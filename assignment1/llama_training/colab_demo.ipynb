# %% [markdown]
# ###  Mount Google Drive

# %%
import os

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

! mkdir -p /content/drive/MyDrive/COMP4901B-Homework1

# %% [markdown]
# ### Clone Codebase

# %%
! mkdir -p /content/drive/MyDrive/COMP4901B-Homework1
! cd /content/drive/MyDrive/COMP4901B-Homework1 && git clone https://github.com/hkust-nlp/COMP4901B-LLMs.git

# %% [markdown]
# ### Download Dataset

# %%
! cd /content/drive/MyDrive/COMP4901B-Homework1/COMP4901B-LLMs/assignment1/llama_training && bash download_data.sh

# %% [markdown]
# ### Start The Training

# %%
! cd /content/drive/MyDrive/COMP4901B-Homework1/COMP4901B-LLMs/assignment1/ && bash run_babylm.sh
